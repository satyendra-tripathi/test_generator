# %% [markdown]
# ## Subject-wise Practice Test Generator (Colab Execution)
# **NOTE:** Make sure you upload the zipped project contents to `/content/testgenerator.zip` OR upload the unzipped files straight into `/content/` before running this cell.

# %%
# !unzip -od /content /content/testgenerator.zip  # Optional: Unzip if you uploaded a zip
# !pip install pyngrok flask werkzeug spacy
# !python -m spacy download en_core_web_sm

# %%
import os
import pyngrok.ngrok as ngrok
import threading

# IMPORTANT: Enter your Ngrok Authtoken here!
# You can get one for free at https://dashboard.ngrok.com/get-started/your-authtoken
NGROK_TOKEN = "YOUR_NGROK_TOKEN_HERE"

ngrok.set_auth_token(NGROK_TOKEN)

# Initialize the database
# !python init_db.py

# Expose Port 5000 via Ngrok
public_url = ngrok.connect(5000)
print("==========================================================")
print(f"\n👉 FLASK APP PUBLIC URL: {public_url}\n")
print("==========================================================")

# Run the flask server
# !python app.py
